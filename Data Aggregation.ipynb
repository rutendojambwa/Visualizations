# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('obama.csv',parse_dates=['year_month'])
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
plt.plot(data.year_month,data.approve_percent,'o',markersize=2,alpha=0.3)
plt.show()

# %%
#aggregating using mean and median
data_mean=data.groupby('year_month').mean()
data_median=data.groupby('year_month').median()
plt.plot(data_mean.index,data_mean.approve_percent,'red')
plt.plot(data_median.index,data_median.approve_percent,'green')
plt.legend(['Mean','Median'])
plt.plot(data.year_month,data.approve_percent,'o',markersize=2,alpha=0.3)
plt.show()

# %%
data_25=data.groupby('year_month').quantile(0.25)
data_75=data.groupby('year_month').quantile(0.75)
plt.plot(data_75.index,data_75.approve_percent,'red')
plt.plot(data_median.index,data_median.approve_percent,'green')
plt.plot(data_25.index,data_25.approve_percent,'blue')
plt.legend(['75th Percentile','Median','25th Percentile'])
plt.plot(data.year_month,data.approve_percent,'o',markersize=2,alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-d32b4f99579b> in <module>
# ----> 1 data_25=data.groupby('year_month').quantile(0.25)
#       2 data_75=data.groupby('year_month').quantile(0.75)
#       3 plt.plot(data_75.index,data_75.approve_percent,'red')
#       4 plt.plot(data_median.index,data_median.approve_percent,'green')
#       5 plt.plot(data_25.index,data_25.approve_percent,'blue')
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in quantile(self, q, interpolation)
#    1903
#    1904         if is_scalar(q):
# -> 1905             return self._get_cythonized_result(
#    1906                 "group_quantile",
#    1907                 aggregate=True,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _get_cythonized_result(self, how, cython_dtype, aggregate, needs_values, needs_mask, needs_ngroups, result_is_index, pre_processing, post_processing, **kwargs)
#    2280                 vals = values
#    2281                 if pre_processing:
# -> 2282                     vals, inferences = pre_processing(vals)
#    2283                 func = partial(func, vals)
#    2284
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in pre_processor(vals)
#    1878         def pre_processor(vals: np.ndarray) -> Tuple[np.ndarray, Optional[Type]]:
#    1879             if is_object_dtype(vals):
# -> 1880                 raise TypeError(
#    1881                     "'quantile' cannot be performed against 'object' dtypes!"
#    1882                 )
#
# TypeError: 'quantile' cannot be performed against 'object' dtypes!
